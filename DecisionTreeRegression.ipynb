# %% [markdown]
# <a href="https://colab.research.google.com/github/buttaakhil/Decision-Tree-Regression/blob/main/DecisionTreeRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("Salary_Data.csv")
print(dataset.head(3))
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["Salary"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree

# %%
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
print(dt.score(x_test,y_test)*100)
# Out:
# 78.81574448805704

# %%
plot_tree(dt)
plt.show()
